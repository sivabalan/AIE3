# %% [markdown]
# <a href="https://colab.research.google.com/github/vgkienzler/ai-engineering-notebooks/blob/main/development_environment_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How to use Google Colab
#
# This notebook quickly introduces how to use Google Colab notebooks, and provides a few tricks that will make your life easier.

# %% [markdown]
# ## Using secrets/environment variables
#
# Secrets are important, as we use a lot of API Keys (HuggingFace, OpenAI, LangcChain, WandDB, etc).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   **Secrets are never shared**, only visible to you and the notebooks that have access to them
# * All your secrets are accessible from all your Colab notebooks so no need to re-enter them
# *   To use a secret, use the code below:

# %%
from google.colab import userdata

test_secret = userdata.get('TEST_SECRET')

print(test_secret)
# Out:
# this is a test secret

# %% [markdown]
# ## Copying and saving to GitHub directly

# %% [markdown]
# 1.   First, **copy the shared notebook to your drive!** Important if you want to be able to edit and play around

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Make sure that all the secrets (API keys) are available
# 3. Edit the new notebook which is located in your drive
# 4. **Save a copy to your gitHub account** if you want, directly from the notebook. For this to work you will need to already have a repository and a branch to save to

# %% [markdown]
# ## Selecting compute and memory

# %% [markdown]
# * On the top right corner, click the arrow
#
# * Select 'Change runtime Type'
#
# Note that not all runtime are available on the free plan, at all any time (A100 GPU for example)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Select the type of compute you need

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Sharing your notebook

# %% [markdown]
# ❗Don't forget to share your notebook so that whoever has the link can view it, before you add it to the Home Work submission form. To do so:
#
#
# * Click on share on the upper left corner
# * Select `Anyone with the link` and `viewer`
# * Click on `Copy link`
# * Paste the link on your HW submission form

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Other helpful tricks

# %% [markdown]
# ### Get an overview of the notebook and navigate easily

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Run several cells at once

# %% [markdown]
# * Menu `Runtime` / `Run All` to run all the notebook at once
#
# * Menu `Runtime` / `Run Before` to run all the cells before the current active cell

# %% [markdown]
# ![image.png](data:image/png;base64,...)
